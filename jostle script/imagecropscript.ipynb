# %%
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt

# %%
# cropping fucnction

def crop(img, email, fileExt):
        # get the dimensions of the image
        height, width, channels = img.shape
        crop_img = img[560:1150, 500:960]
        cv2.imwrite("\\\\howard\\01 - Technology Services\\13 - Media Files\\03 - ID Badges\\03 - Jostle Pictures\\03 - ALL Photos\\Edited in Script\\" + email + fileExt, crop_img)
        print(crop_img.shape)

# %%
# create pandas dataframe from the updated csv file
df = pd.read_csv("\\\\howard\\01 - Technology Services\\13 - Media Files\\03 - ID Badges\\03 - Jostle Pictures\\jostleNoPhoto.csv", encoding='utf-8', low_memory=False)
print(df)
# Out:
#                        WorkEmail  FirstName  LastName
# 0        rbach@mywinterhaven.com     Ronald      Bach
# 1       sbyers@mywinterhaven.com       Sean     Byers
# 2    mwilliams@mywinterhaven.com    Michael  Williams
# 3     ggardner@mywinterhaven.com  Gabrielle   Gardner
# 4      jcrosby@mywinterhaven.com     Joshua    Crosby
# ..                           ...        ...       ...
# 225   avaughan@mywinterhaven.com     Adrian   Vaughan
# 226  hbraswell@mywinterhaven.com     Hannah  Braswell
# 227    fmacias@mywinterhaven.com     Franky    Macias
# 228   dmahalik@mywinterhaven.com      David   Mahalik
# 229   tjenkins@mywinterhaven.com  Taizhuana   Jenkins
#
# [230 rows x 3 columns]

# %%
# iterate through all photos
for file in os.listdir("\\\\howard\\01 - Technology Services\\13 - Media Files\\03 - ID Badges\\03 - Jostle Pictures\\03 - ALL Photos"):
    if file.endswith(".jpg") or file.endswith(".jpeg") or file.endswith(".png"):
        # for each photo, take just the first element of the name
        name = file.split(" ")
        name = name[0].strip(",")
        print(name)

        # check if the "last name" is in the pandas dataframe
        if name in df['FirstName'].values:
            print("Name found in the dataframe: " + name)
            # get the row of the dataframe that contains that name
            row = df.loc[df['FirstName'] == name]
            print(row)
            # get the "WorkEmail" column of that row as a string
            email = row['WorkEmail'].values[0]
            (print(email))
            # perform the cropping operation
            img = cv2.imread("\\\\howard\\01 - Technology Services\\13 - Media Files\\03 - ID Badges\\03 - Jostle Pictures\\03 - ALL Photos\\" + file)
            fileExt = os.path.splitext(file)[1]
            crop(img, email, fileExt)
        else:
            print("Name not found in the dataframe: " + name)
        
        break
# Out:
# Aaron
# Name found in the dataframe: Aaron
#                      WorkEmail FirstName LastName
# 27  arussell@mywinterhaven.com     Aaron  Russell
# arussell@mywinterhaven.com
# (590, 460, 3)
# Aaron Russell.png Aaron Russell

# %%
for file in os.listdir("\\\\howard\\01 - Technology Services\\13 - Media Files\\03 - ID Badges\\03 - Jostle Pictures\\03 - ALL Photos"):
    if file.endswith(".jpg"):
        # read the image
        img = cv2.imread("\\\\howard\\01 - Technology Services\\13 - Media Files\\03 - ID Badges\\03 - Jostle Pictures\\03 - ALL Photos\\" + file)
        # get the dimensions of the image
        height, width, channels = img.shape
        # print the dimensions
        print(f"{file}: {height}x{width}x{channels}")
        #img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        # check if the image is 300x300 pixels
        crop_img = img[560:1150, 500:960]
        # plt.imshow(crop_img)
        # plt.show()
        cv2.imwrite("\\\\howard\\01 - Technology Services\\13 - Media Files\\03 - ID Badges\\03 - Jostle Pictures\\03 - ALL Photos\\Edited in Script\\" + file, crop_img)
        print(crop_img.shape)
        break
# Out:
# PW_BALL, KAREN.jpg: 1685x1060x3
# [[[123 169 200]
#   [117 168 200]
#   [122 169 200]
#   ...
#   [120 169 201]
#   [122 169 200]
#   [124 168 199]]
#
#  [[199 215 244]
#   [199 215 244]
#   [196 217 244]
#   ...
#   [193 215 243]
#   [195 214 241]
#   [196 212 235]]
#
#  [[201 221 246]
#   [202 219 246]
#   [200 222 247]
#   ...
#   [200 218 247]
#   [204 218 241]
#   [203 214 234]]
#
#  ...
#
#  [[127 107  90]
#   [126  56  27]
#   [150  53  27]
#   ...
#   [141 107  84]
#   [200 161  83]
#   [177 144  41]]
#
#  [[ 67  73  72]
#   [124  59  38]
#   [160  57  25]
#   ...
#   [137 105  70]
#   [200 169  94]
#   [175 143  48]]
#
#  [[ 67  94 120]
#   [130  60  43]
#   [151  56  17]
#   ...
#   [120  94  64]
#   [187 167  80]
#   [187 153  70]]] (590, 460, 3)

# %%
# CHATGPT 2
import os
import pandas as pd
import cv2

# your directories
INPUT_DIR  = r"C:\Users\dtaylor\Documents\Jostle Pictures Project\ALLIDS"
OUTPUT_DIR = r"C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3"
CSV_PATH   = r"C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleAllUsers_WE_FN_LN.csv"

os.makedirs(OUTPUT_DIR, exist_ok=True)

# load your DataFrame
df = pd.read_csv(CSV_PATH, encoding='utf-8', low_memory=False)

# 1) Strip whitespace off all column names
df.columns = df.columns.str.strip()

# 2) Rename columns if they’re not already 'FirstName'/'LastName'
#    (adjust the left-hand keys to whatever your CSV actually uses)
df.rename(columns={
    'First Name': 'FirstName',
    'Last Name':  'LastName',
    'first_name': 'FirstName',
    'last_name':  'LastName',
}, inplace=True)

print("Columns in DataFrame now:", df.columns.tolist())

def crop_and_save(img_path: str, email: str, file_ext: str):
    img = cv2.imread(img_path)
    if img is None:
        print(f"[ERROR] failed to load image: {img_path}")
        return
    crop_img = img[563:1150, 500:960]
    out_path = os.path.join(OUTPUT_DIR, f"{email}{file_ext}")
    if cv2.imwrite(out_path, crop_img):
        print(f"[OK] cropped & saved → {out_path}")
    else:
        print(f"[ERROR] could not save to {out_path}")

for fname in os.listdir(INPUT_DIR):
    low = fname.lower()
    if not (low.endswith(".jpg") or low.endswith(".jpeg") or low.endswith(".png")):
        continue


    base, ext = os.path.splitext(fname)
    print(f"\nProcessing file: {fname!r}")

    # Extract first and last name:
    if "," in base:
        last_name, rest = base.split(",", 1)
        last_name = last_name.strip()
        first_name = rest.strip().split()[0]
    elif " " in base:
        parts     = base.split()
        first_name = parts[0].strip()
        last_name  = parts[-1].strip()
    else:
        print(f"[SKIP] can't parse name from {base!r}")
        continue

    print(f"  Parsed FirstName={first_name!r}, LastName={last_name!r}")

    # ---- Now this will succeed because we've ensured the cols exist ----
    mask  = (df['FirstName'] == first_name) & (df['LastName'] == last_name)
    count = mask.sum()

    if count == 1:
        row   = df.loc[mask].iloc[0]
        email = row['WorkEmail']
        print(f"[MATCH] {first_name} {last_name} → {email}")
        crop_and_save(
            os.path.join(INPUT_DIR, fname),
            email,
            ext
        )
    elif count > 1:
        print(f"[AMBIGUOUS] {count} matches for {first_name} {last_name}")
    else:
        print(f"[NOT FOUND] no match for {first_name} {last_name}")
# Out:
# Columns in DataFrame now: ['WorkEmail', 'FirstName', 'LastName']
#
# Processing file: 'abdeljawad, ahmad z done.png'
#   Parsed FirstName='ahmad', LastName='abdeljawad'
# [MATCH] ahmad abdeljawad → aabdeljawad@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\aabdeljawad@mywinterhaven.com.png
#
# Processing file: 'adams, julie m done.png'
#   Parsed FirstName='julie', LastName='adams'
# [MATCH] julie adams → jadams@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jadams@mywinterhaven.com.png
#
# Processing file: 'adamson, jonathan m done.png'
#   Parsed FirstName='jonathan', LastName='adamson'
# [MATCH] jonathan adamson → jadamson@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jadamson@mywinterhaven.com.png
#
# Processing file: 'alan mccullough.png'
#   Parsed FirstName='alan', LastName='mccullough'
# [MATCH] alan mccullough → amccullough@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\amccullough@mywinterhaven.com.png
#
# Processing file: 'albarran, silbano done.png'
#   Parsed FirstName='silbano', LastName='albarran'
# [MATCH] silbano albarran → salbarran@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\salbarran@mywinterhaven.com.png
#
# Processing file: 'alexandther cartagena-san chez.png'
#   Parsed FirstName='alexandther', LastName='chez'
# [NOT FOUND] no match for alexandther chez
#
# Processing file: 'alfonso ibarra-contreras.png'
#   Parsed FirstName='alfonso', LastName='ibarra-contreras'
# [NOT FOUND] no match for alfonso ibarra-contreras
#
# Processing file: 'arcides pagan.png'
#   Parsed FirstName='arcides', LastName='pagan'
# [NOT FOUND] no match for arcides pagan
#
# Processing file: 'bacarra, nicholas m.png'
#   Parsed FirstName='nicholas', LastName='bacarra'
# [MATCH] nicholas bacarra → nbacarra@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\nbacarra@mywinterhaven.com.png
#
# Processing file: 'baker, johnnie jr_.png'
#   Parsed FirstName='johnnie', LastName='baker'
# [MATCH] johnnie baker → jbaker@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jbaker@mywinterhaven.com.png
#
# Processing file: 'balderas, martindone.png'
#   Parsed FirstName='martindone', LastName='balderas'
# [NOT FOUND] no match for martindone balderas
#
# Processing file: 'ball, karen.jpg'
#   Parsed FirstName='karen', LastName='ball'
# [MATCH] karen ball → kball@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\kball@mywinterhaven.com.jpg
#
# Processing file: 'barbara watson.png'
#   Parsed FirstName='barbara', LastName='watson'
# [MATCH] barbara watson → bwatson@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\bwatson@mywinterhaven.com.png
#
# Processing file: 'barron, william k.png'
#   Parsed FirstName='william', LastName='barron'
# [MATCH] william barron → wbarron@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\wbarron@mywinterhaven.com.png
#
# Processing file: 'bentley, earl e.png'
#   Parsed FirstName='earl', LastName='bentley'
# [MATCH] earl bentley → ebentley@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ebentley@mywinterhaven.com.png
#
# Processing file: 'berg, patricia d done.png'
#   Parsed FirstName='patricia', LastName='berg'
# [MATCH] patricia berg → pberg@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\pberg@mywinterhaven.com.png
#
# Processing file: 'berrios-cintron, pedro a  done.png'
#   Parsed FirstName='pedro', LastName='berrios-cintron'
# [MATCH] pedro berrios-cintron → pberrios@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\pberrios@mywinterhaven.com.png
#
# Processing file: 'berry, demetrius l done.png'
#   Parsed FirstName='demetrius', LastName='berry'
# [NOT FOUND] no match for demetrius berry
#
# Processing file: 'berry, megan.jpg'
#   Parsed FirstName='megan', LastName='berry'
# [NOT FOUND] no match for megan berry
#
# Processing file: 'best, tyler j done.png'
#   Parsed FirstName='tyler', LastName='best'
# [MATCH] tyler best → tbest@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\tbest@mywinterhaven.com.png
#
# Processing file: 'bhawanidin, richard.png'
#   Parsed FirstName='richard', LastName='bhawanidin'
# [NOT FOUND] no match for richard bhawanidin
#
# Processing file: 'biller, daniel w done.png'
#   Parsed FirstName='daniel', LastName='biller'
# [MATCH] daniel biller → dbiller@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\dbiller@mywinterhaven.com.png
#
# Processing file: 'black, joseph done.png'
#   Parsed FirstName='joseph', LastName='black'
# [MATCH] joseph black → jblack@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jblack@mywinterhaven.com.png
#
# Processing file: 'blind, jason m done.png'
#   Parsed FirstName='jason', LastName='blind'
# [MATCH] jason blind → jblind@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jblind@mywinterhaven.com.png
#
# Processing file: 'blits, john.jpg'
#   Parsed FirstName='john', LastName='blits'
# [MATCH] john blits → jblits@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jblits@mywinterhaven.com.jpg
#
# Processing file: 'blount, sean done.png'
#   Parsed FirstName='sean', LastName='blount'
# [MATCH] sean blount → sblount@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\sblount@mywinterhaven.com.png
#
# Processing file: 'blythe, derry l done.png'
#   Parsed FirstName='derry', LastName='blythe'
# [MATCH] derry blythe → dblythe@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\dblythe@mywinterhaven.com.png
#
# Processing file: 'boatwright, quinton r done.png'
#   Parsed FirstName='quinton', LastName='boatwright'
# [MATCH] quinton boatwright → qboatwright@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\qboatwright@mywinterhaven.com.png
#
# Processing file: 'bombard, mark w done.png'
#   Parsed FirstName='mark', LastName='bombard'
# [MATCH] mark bombard → mbombard@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\mbombard@mywinterhaven.com.png
#
# Processing file: 'borga, brandon done.png'
#   Parsed FirstName='brandon', LastName='borga'
# [MATCH] brandon borga → bborga@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\bborga@mywinterhaven.com.png
#
# Processing file: 'boston, michelle p.png'
#   Parsed FirstName='michelle', LastName='boston'
# [MATCH] michelle boston → mboston@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\mboston@mywinterhaven.com.png
#
# Processing file: 'bottega mendoza, adriana r done.png'
#   Parsed FirstName='adriana', LastName='bottega mendoza'
# [NOT FOUND] no match for adriana bottega mendoza
#
# Processing file: 'bowen, terrence m.jpg'
#   Parsed FirstName='terrence', LastName='bowen'
# [MATCH] terrence bowen → tbowen@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\tbowen@mywinterhaven.com.jpg
#
# Processing file: 'brannan, hope l done.png'
#   Parsed FirstName='hope', LastName='brannan'
# [MATCH] hope brannan → hbrannan@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\hbrannan@mywinterhaven.com.png
#
# Processing file: 'brown, michael j done.png'
#   Parsed FirstName='michael', LastName='brown'
# [MATCH] michael brown → mbrown@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\mbrown@mywinterhaven.com.png
#
# Processing file: 'brown, parker j done.png'
#   Parsed FirstName='parker', LastName='brown'
# [MATCH] parker brown → pbrown@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\pbrown@mywinterhaven.com.png
#
# Processing file: 'bruce hurt.png'
#   Parsed FirstName='bruce', LastName='hurt'
# [NOT FOUND] no match for bruce hurt
#
# Processing file: 'burke, jennifer e done.png'
#   Parsed FirstName='jennifer', LastName='burke'
# [MATCH] jennifer burke → jburke@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jburke@mywinterhaven.com.png
#
# Processing file: 'burnham, okoki d done.png'
#   Parsed FirstName='okoki', LastName='burnham'
# [MATCH] okoki burnham → oburnham@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\oburnham@mywinterhaven.com.png
#
# Processing file: 'bussiere, brandon c done.png'
#   Parsed FirstName='brandon', LastName='bussiere'
# [MATCH] brandon bussiere → bbussiere@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\bbussiere@mywinterhaven.com.png
#
# Processing file: 'butler, adam f done.png'
#   Parsed FirstName='adam', LastName='butler'
# [MATCH] adam butler → abutler@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\abutler@mywinterhaven.com.png
#
# Processing file: 'byers, sean h done.png'
#   Parsed FirstName='sean', LastName='byers'
# [MATCH] sean byers → sbyers@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\sbyers@mywinterhaven.com.png
#
# Processing file: 'cabeceira, james m.png'
#   Parsed FirstName='james', LastName='cabeceira'
# [NOT FOUND] no match for james cabeceira
#
# Processing file: 'cadet, gary.png'
#   Parsed FirstName='gary', LastName='cadet'
# [MATCH] gary cadet → gcadet@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\gcadet@mywinterhaven.com.png
#
# Processing file: 'campbell, michael w.jpg'
#   Parsed FirstName='michael', LastName='campbell'
# [MATCH] michael campbell → mcampbell@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\mcampbell@mywinterhaven.com.jpg
#
# Processing file: 'carnevale, michael j done.png'
#   Parsed FirstName='michael', LastName='carnevale'
# [MATCH] michael carnevale → mcarnevale@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\mcarnevale@mywinterhaven.com.png
#
# Processing file: 'carnley, john c.jpg'
#   Parsed FirstName='john', LastName='carnley'
# [MATCH] john carnley → jcarnley@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jcarnley@mywinterhaven.com.jpg
#
# Processing file: 'carson, clyde.jpg'
#   Parsed FirstName='clyde', LastName='carson'
# [MATCH] clyde carson → ccarson@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ccarson@mywinterhaven.com.jpg
#
# Processing file: 'cartagena-sanchez, alexandther.jpg'
#   Parsed FirstName='alexandther', LastName='cartagena-sanchez'
# [NOT FOUND] no match for alexandther cartagena-sanchez
#
# Processing file: 'castillo, vanessa done.png'
#   Parsed FirstName='vanessa', LastName='castillo'
# [MATCH] vanessa castillo → vcastillo@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\vcastillo@mywinterhaven.com.png
#
# Processing file: 'castro igartua, dexter a.png'
#   Parsed FirstName='dexter', LastName='castro igartua'
# [NOT FOUND] no match for dexter castro igartua
#
# Processing file: 'castro-robles, alejandro j done.png'
#   Parsed FirstName='alejandro', LastName='castro-robles'
# [NOT FOUND] no match for alejandro castro-robles
#
# Processing file: 'charles, hodney.jpg'
#   Parsed FirstName='hodney', LastName='charles'
# [MATCH] hodney charles → hcharles@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\hcharles@mywinterhaven.com.jpg
#
# Processing file: 'charles, jean m done.png'
#   Parsed FirstName='jean', LastName='charles'
# [MATCH] jean charles → jcharles@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jcharles@mywinterhaven.com.png
#
# Processing file: 'charneco, maria.jpg'
#   Parsed FirstName='maria', LastName='charneco'
# [MATCH] maria charneco → mcharneco@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\mcharneco@mywinterhaven.com.jpg
#
# Processing file: 'chaves, rafael a.png'
#   Parsed FirstName='rafael', LastName='chaves'
# [NOT FOUND] no match for rafael chaves
#
# Processing file: 'christopher rigby.png'
#   Parsed FirstName='christopher', LastName='rigby'
# [MATCH] christopher rigby → crigby@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\crigby@mywinterhaven.com.png
#
# Processing file: 'clark, jennifer l done.png'
#   Parsed FirstName='jennifer', LastName='clark'
# [MATCH] jennifer clark → jclark@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jclark@mywinterhaven.com.png
#
# Processing file: 'clayton, michael a.jpg'
#   Parsed FirstName='michael', LastName='clayton'
# [MATCH] michael clayton → mclayton@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\mclayton@mywinterhaven.com.jpg
#
# Processing file: 'clyde carson.png'
#   Parsed FirstName='clyde', LastName='carson'
# [MATCH] clyde carson → ccarson@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ccarson@mywinterhaven.com.png
#
# Processing file: 'cohagen, nicole l done.png'
#   Parsed FirstName='nicole', LastName='cohagen'
# [MATCH] nicole cohagen → ncohagen@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ncohagen@mywinterhaven.com.png
#
# Processing file: 'collins, devon j done.png'
#   Parsed FirstName='devon', LastName='collins'
# [MATCH] devon collins → dcollins@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\dcollins@mywinterhaven.com.png
#
# Processing file: 'conrad, cody r done.png'
#   Parsed FirstName='cody', LastName='conrad'
# [MATCH] cody conrad → cconrad@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\cconrad@mywinterhaven.com.png
#
# Processing file: 'coombs, gregory c.jpg'
#   Parsed FirstName='gregory', LastName='coombs'
# [NOT FOUND] no match for gregory coombs
#
# Processing file: 'corby, luann.jpg'
#   Parsed FirstName='luann', LastName='corby'
# [MATCH] luann corby → lcorby@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\lcorby@mywinterhaven.com.jpg
#
# Processing file: 'cox, cedric h done.png'
#   Parsed FirstName='cedric', LastName='cox'
# [MATCH] cedric cox → ccox@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ccox@mywinterhaven.com.png
#
# Processing file: 'craig, michael s.jpg'
#   Parsed FirstName='michael', LastName='craig'
# [NOT FOUND] no match for michael craig
#
# Processing file: 'crespo, maribel done.png'
#   Parsed FirstName='maribel', LastName='crespo'
# [MATCH] maribel crespo → mcrespo@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\mcrespo@mywinterhaven.com.png
#
# Processing file: 'crosby, joshua.jpg'
#   Parsed FirstName='joshua', LastName='crosby'
# [MATCH] joshua crosby → jcrosby@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jcrosby@mywinterhaven.com.jpg
#
# Processing file: 'crosby, tommy w.jpg'
#   Parsed FirstName='tommy', LastName='crosby'
# [NOT FOUND] no match for tommy crosby
#
# Processing file: 'crouse, jeffrey m done.png'
#   Parsed FirstName='jeffrey', LastName='crouse'
# [MATCH] jeffrey crouse → jcrouse@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jcrouse@mywinterhaven.com.png
#
# Processing file: 'cruz, jose r done.png'
#   Parsed FirstName='jose', LastName='cruz'
# [NOT FOUND] no match for jose cruz
#
# Processing file: 'david griffith.png'
#   Parsed FirstName='david', LastName='griffith'
# [MATCH] david griffith → dgriffith@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\dgriffith@mywinterhaven.com.png
#
# Processing file: 'david hebb.png'
#   Parsed FirstName='david', LastName='hebb'
# [MATCH] david hebb → dhebb@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\dhebb@mywinterhaven.com.png
#
# Processing file: 'david micheal dean.png'
#   Parsed FirstName='david', LastName='dean'
# [MATCH] david dean → ddean@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ddean@mywinterhaven.com.png
#
# Processing file: 'david, venita h.jpg'
#   Parsed FirstName='venita', LastName='david'
# [MATCH] venita david → vdavid@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\vdavid@mywinterhaven.com.jpg
#
# Processing file: 'davis, jocelyn s.png'
#   Parsed FirstName='jocelyn', LastName='davis'
# [MATCH] jocelyn davis → jsdavis@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jsdavis@mywinterhaven.com.png
#
# Processing file: 'dean, daivd michael.jpg'
#   Parsed FirstName='daivd', LastName='dean'
# [NOT FOUND] no match for daivd dean
#
# Processing file: 'dejesus-alvarado, carlos done.png'
#   Parsed FirstName='carlos', LastName='dejesus-alvarado'
# [MATCH] carlos dejesus-alvarado → cdejesus@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\cdejesus@mywinterhaven.com.png
#
# Processing file: 'delroy lewis.png'
#   Parsed FirstName='delroy', LastName='lewis'
# [NOT FOUND] no match for delroy lewis
#
# Processing file: 'dietiker, christopher c done.png'
#   Parsed FirstName='christopher', LastName='dietiker'
# [MATCH] christopher dietiker → cdietiker@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\cdietiker@mywinterhaven.com.png
#
# Processing file: 'ditty, nicholas t done.png'
#   Parsed FirstName='nicholas', LastName='ditty'
# [NOT FOUND] no match for nicholas ditty
#
# Processing file: 'dominguez, stephanie l done.png'
#   Parsed FirstName='stephanie', LastName='dominguez'
# [MATCH] stephanie dominguez → sdominguez@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\sdominguez@mywinterhaven.com.png
#
# Processing file: 'donnelly, stephen p done.png'
#   Parsed FirstName='stephen', LastName='donnelly'
# [MATCH] stephen donnelly → sdonnelly@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\sdonnelly@mywinterhaven.com.png
#
# Processing file: 'donohue, brian r done.png'
#   Parsed FirstName='brian', LastName='donohue'
# [MATCH] brian donohue → bdonohue@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\bdonohue@mywinterhaven.com.png
#
# Processing file: 'dopp, ruth a done.png'
#   Parsed FirstName='ruth', LastName='dopp'
# [MATCH] ruth dopp → rdopp@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\rdopp@mywinterhaven.com.png
#
# Processing file: 'dudley, jamie d.png'
#   Parsed FirstName='jamie', LastName='dudley'
# [MATCH] jamie dudley → jdudley@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jdudley@mywinterhaven.com.png
#
# Processing file: 'duncan, tanisha n done.png'
#   Parsed FirstName='tanisha', LastName='duncan'
# [MATCH] tanisha duncan → tduncan@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\tduncan@mywinterhaven.com.png
#
# Processing file: 'dustin everitt.png'
#   Parsed FirstName='dustin', LastName='everitt'
# [MATCH] dustin everitt → deveritt@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\deveritt@mywinterhaven.com.png
#
# Processing file: 'dykes, shawn b done.png'
#   Parsed FirstName='shawn', LastName='dykes'
# [MATCH] shawn dykes → sdykes@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\sdykes@mywinterhaven.com.png
#
# Processing file: 'edward kester jr.png'
#   Parsed FirstName='edward', LastName='jr'
# [NOT FOUND] no match for edward jr
#
# Processing file: 'edwards, travis jr_.png'
#   Parsed FirstName='travis', LastName='edwards'
# [NOT FOUND] no match for travis edwards
#
# Processing file: 'eilers, scott e done.png'
#   Parsed FirstName='scott', LastName='eilers'
# [MATCH] scott eilers → seilers@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\seilers@mywinterhaven.com.png
#
# Processing file: 'eliud hernandez.png'
#   Parsed FirstName='eliud', LastName='hernandez'
# [MATCH] eliud hernandez → ehernandez@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ehernandez@mywinterhaven.com.png
#
# Processing file: 'everitt, dustin w.jpg'
#   Parsed FirstName='dustin', LastName='everitt'
# [MATCH] dustin everitt → deveritt@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\deveritt@mywinterhaven.com.jpg
#
# Processing file: 'fairbanks, kevin d.jpg'
#   Parsed FirstName='kevin', LastName='fairbanks'
# [NOT FOUND] no match for kevin fairbanks
#
# Processing file: 'fenton, stanley m done.png'
#   Parsed FirstName='stanley', LastName='fenton'
# [MATCH] stanley fenton → sfenton@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\sfenton@mywinterhaven.com.png
#
# Processing file: 'fernandez, ramon done.png'
#   Parsed FirstName='ramon', LastName='fernandez'
# [MATCH] ramon fernandez → rfernandez@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\rfernandez@mywinterhaven.com.png
#
# Processing file: 'fetter, colin j.png'
#   Parsed FirstName='colin', LastName='fetter'
# [NOT FOUND] no match for colin fetter
#
# Processing file: 'figueroa-acevedo, eliexer done.png'
#   Parsed FirstName='eliexer', LastName='figueroa-acevedo'
# [MATCH] eliexer figueroa-acevedo → efigueroaacevedo@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\efigueroaacevedo@mywinterhaven.com.png
#
# Processing file: 'forsell, scott w.png'
#   Parsed FirstName='scott', LastName='forsell'
# [NOT FOUND] no match for scott forsell
#
# Processing file: 'foster, george m done.png'
#   Parsed FirstName='george', LastName='foster'
# [NOT FOUND] no match for george foster
#
# Processing file: 'fox, gabriel a.png'
#   Parsed FirstName='gabriel', LastName='fox'
# [NOT FOUND] no match for gabriel fox
#
# Processing file: 'fox, gavin a.png'
#   Parsed FirstName='gavin', LastName='fox'
# [MATCH] gavin fox → gfox@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\gfox@mywinterhaven.com.png
#
# Processing file: 'francois, karen done.png'
#   Parsed FirstName='karen', LastName='francois'
# [MATCH] karen francois → kfrancois@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\kfrancois@mywinterhaven.com.png
#
# Processing file: 'frank hyman.png'
#   Parsed FirstName='frank', LastName='hyman'
# [NOT FOUND] no match for frank hyman
#
# Processing file: 'frank, kenneth a.jpg'
#   Parsed FirstName='kenneth', LastName='frank'
# [MATCH] kenneth frank → kfrank@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\kfrank@mywinterhaven.com.jpg
#
# Processing file: 'gabany, trai c done.png'
#   Parsed FirstName='trai', LastName='gabany'
# [MATCH] trai gabany → tgabany@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\tgabany@mywinterhaven.com.png
#
# Processing file: 'galindo, victoria m done.png'
#   Parsed FirstName='victoria', LastName='galindo'
# [MATCH] victoria galindo → vgalindo@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\vgalindo@mywinterhaven.com.png
#
# Processing file: 'garay, eli j done.png'
#   Parsed FirstName='eli', LastName='garay'
# [MATCH] eli garay → egaray@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\egaray@mywinterhaven.com.png
#
# Processing file: 'garcia, freddy e done.png'
#   Parsed FirstName='freddy', LastName='garcia'
# [MATCH] freddy garcia → Fgarcia@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\Fgarcia@mywinterhaven.com.png
#
# Processing file: 'garcia, ivan.jpg'
#   Parsed FirstName='ivan', LastName='garcia'
# [MATCH] ivan garcia → igarcia@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\igarcia@mywinterhaven.com.jpg
#
# Processing file: 'gardner, gabrielle done.png'
#   Parsed FirstName='gabrielle', LastName='gardner'
# [MATCH] gabrielle gardner → ggardner@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ggardner@mywinterhaven.com.png
#
# Processing file: 'giles, maggie done.png'
#   Parsed FirstName='maggie', LastName='giles'
# [MATCH] maggie giles → mgiles@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\mgiles@mywinterhaven.com.png
#
# Processing file: 'glover, dalton l done.png'
#   Parsed FirstName='dalton', LastName='glover'
# [MATCH] dalton glover → dglover@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\dglover@mywinterhaven.com.png
#
# Processing file: 'golden, lisa i.png'
#   Parsed FirstName='lisa', LastName='golden'
# [MATCH] lisa golden → lgolden@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\lgolden@mywinterhaven.com.png
#
# Processing file: 'gomez fuentes, jesus done.png'
#   Parsed FirstName='jesus', LastName='gomez fuentes'
# [NOT FOUND] no match for jesus gomez fuentes
#
# Processing file: 'gonzalez, raul jr. done.png'
#   Parsed FirstName='raul', LastName='gonzalez'
# [MATCH] raul gonzalez → ragonzalez@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ragonzalez@mywinterhaven.com.png
#
# Processing file: 'gonzalez, ronald.png'
#   Parsed FirstName='ronald', LastName='gonzalez'
# [MATCH] ronald gonzalez → rgonzalez@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\rgonzalez@mywinterhaven.com.png
#
# Processing file: 'gonzalez-rios, jose a done.png'
#   Parsed FirstName='jose', LastName='gonzalez-rios'
# [MATCH] jose gonzalez-rios → jagonzalez@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jagonzalez@mywinterhaven.com.png
#
# Processing file: 'gooding, larry t (1).jpg'
#   Parsed FirstName='larry', LastName='gooding'
# [NOT FOUND] no match for larry gooding
#
# Processing file: 'gooding, larry t (2).jpg'
#   Parsed FirstName='larry', LastName='gooding'
# [NOT FOUND] no match for larry gooding
#
# Processing file: 'gooding, larry t done.png'
#   Parsed FirstName='larry', LastName='gooding'
# [NOT FOUND] no match for larry gooding
#
# Processing file: 'graham, michael g.png'
#   Parsed FirstName='michael', LastName='graham'
# [MATCH] michael graham → mgraham@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\mgraham@mywinterhaven.com.png
#
# Processing file: 'greear, cori s done.png'
#   Parsed FirstName='cori', LastName='greear'
# [MATCH] cori greear → cgreear@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\cgreear@mywinterhaven.com.png
#
# Processing file: 'green, chase j done.png'
#   Parsed FirstName='chase', LastName='green'
# [MATCH] chase green → cgreen@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\cgreen@mywinterhaven.com.png
#
# Processing file: 'greenhow, gary done.png'
#   Parsed FirstName='gary', LastName='greenhow'
# [MATCH] gary greenhow → ggreenhow@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ggreenhow@mywinterhaven.com.png
#
# Processing file: 'gregory coombs.png'
#   Parsed FirstName='gregory', LastName='coombs'
# [NOT FOUND] no match for gregory coombs
#
# Processing file: 'grenier, john r done.png'
#   Parsed FirstName='john', LastName='grenier'
# [NOT FOUND] no match for john grenier
#
# Processing file: 'griffin, picasso r done.png'
#   Parsed FirstName='picasso', LastName='griffin'
# [MATCH] picasso griffin → pgriffin@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\pgriffin@mywinterhaven.com.png
#
# Processing file: 'griffis, kenneth d done.png'
#   Parsed FirstName='kenneth', LastName='griffis'
# [MATCH] kenneth griffis → kgriffis@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\kgriffis@mywinterhaven.com.png
#
# Processing file: 'griffith, david d.jpg'
#   Parsed FirstName='david', LastName='griffith'
# [MATCH] david griffith → dgriffith@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\dgriffith@mywinterhaven.com.jpg
#
# Processing file: 'hall, stanley d done.png'
#   Parsed FirstName='stanley', LastName='hall'
# [MATCH] stanley hall → shall@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\shall@mywinterhaven.com.png
#
# Processing file: 'hammond, timothy w.png'
#   Parsed FirstName='timothy', LastName='hammond'
# [MATCH] timothy hammond → whammond@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\whammond@mywinterhaven.com.png
#
# Processing file: 'hamric, traci d done.png'
#   Parsed FirstName='traci', LastName='hamric'
# [MATCH] traci hamric → thamric@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\thamric@mywinterhaven.com.png
#
# Processing file: 'hanhan, amin done.png'
#   Parsed FirstName='amin', LastName='hanhan'
# [MATCH] amin hanhan → ahanhan@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ahanhan@mywinterhaven.com.png
#
# Processing file: 'harp, anna c done.png'
#   Parsed FirstName='anna', LastName='harp'
# [MATCH] anna harp → aharp@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\aharp@mywinterhaven.com.png
#
# Processing file: 'harris, latonya s done.png'
#   Parsed FirstName='latonya', LastName='harris'
# [MATCH] latonya harris → lharris@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\lharris@mywinterhaven.com.png
#
# Processing file: 'hart, brittany b.png'
#   Parsed FirstName='brittany', LastName='hart'
# [MATCH] brittany hart → bhart@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\bhart@mywinterhaven.com.png
#
# Processing file: 'hart, jessica done.png'
#   Parsed FirstName='jessica', LastName='hart'
# [MATCH] jessica hart → jhart@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jhart@mywinterhaven.com.png
#
# Processing file: 'hatfield, michael c.jpg'
#   Parsed FirstName='michael', LastName='hatfield'
# [MATCH] michael hatfield → mhatfield@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\mhatfield@mywinterhaven.com.jpg
#
# Processing file: 'haynie, tamra l done.png'
#   Parsed FirstName='tamra', LastName='haynie'
# [MATCH] tamra haynie → thaynie@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\thaynie@mywinterhaven.com.png
#
# Processing file: 'hebb, david m.jpg'
#   Parsed FirstName='david', LastName='hebb'
# [MATCH] david hebb → dhebb@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\dhebb@mywinterhaven.com.jpg
#
# Processing file: 'hendrix, joshua l.jpg'
#   Parsed FirstName='joshua', LastName='hendrix'
# [MATCH] joshua hendrix → jhendrix@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jhendrix@mywinterhaven.com.jpg
#
# Processing file: 'hernandez jr., david done.png'
#   Parsed FirstName='david', LastName='hernandez jr.'
# [NOT FOUND] no match for david hernandez jr.
#
# Processing file: 'hernandez, eliud.jpg'
#   Parsed FirstName='eliud', LastName='hernandez'
# [MATCH] eliud hernandez → ehernandez@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ehernandez@mywinterhaven.com.jpg
#
# Processing file: 'hernandez, marianne j.jpg'
#   Parsed FirstName='marianne', LastName='hernandez'
# [MATCH] marianne hernandez → Mhernandez@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\Mhernandez@mywinterhaven.com.jpg
#
# Processing file: 'hibbard, angela c done.png'
#   Parsed FirstName='angela', LastName='hibbard'
# [MATCH] angela hibbard → ahibbard@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ahibbard@mywinterhaven.com.png
#
# Processing file: 'hill, katrina d done.png'
#   Parsed FirstName='katrina', LastName='hill'
# [MATCH] katrina hill → khill@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\khill@mywinterhaven.com.png
#
# Processing file: 'hill, zaria t done.png'
#   Parsed FirstName='zaria', LastName='hill'
# [MATCH] zaria hill → zhill@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\zhill@mywinterhaven.com.png
#
# Processing file: 'hodgson, charles k done.png'
#   Parsed FirstName='charles', LastName='hodgson'
# [NOT FOUND] no match for charles hodgson
#
# Processing file: 'hodney charles.png'
#   Parsed FirstName='hodney', LastName='charles'
# [MATCH] hodney charles → hcharles@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\hcharles@mywinterhaven.com.png
#
# Processing file: 'hogue, chase r done.png'
#   Parsed FirstName='chase', LastName='hogue'
# [MATCH] chase hogue → chogue@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\chogue@mywinterhaven.com.png
#
# Processing file: 'houmard, robert t.png'
#   Parsed FirstName='robert', LastName='houmard'
# [MATCH] robert houmard → rhoumard@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\rhoumard@mywinterhaven.com.png
#
# Processing file: 'howard, brady n done.png'
#   Parsed FirstName='brady', LastName='howard'
# [MATCH] brady howard → bhoward@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\bhoward@mywinterhaven.com.png
#
# Processing file: 'howard, stephanie m done.png'
#   Parsed FirstName='stephanie', LastName='howard'
# [MATCH] stephanie howard → showard@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\showard@mywinterhaven.com.png
#
# Processing file: 'howell, david c jr_.png'
#   Parsed FirstName='david', LastName='howell'
# [MATCH] david howell → dhowell@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\dhowell@mywinterhaven.com.png
#
# Processing file: 'hubbard, gary done.png'
#   Parsed FirstName='gary', LastName='hubbard'
# [MATCH] gary hubbard → ghubbard@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ghubbard@mywinterhaven.com.png
#
# Processing file: 'hurt, bruce.jpg'
#   Parsed FirstName='bruce', LastName='hurt'
# [NOT FOUND] no match for bruce hurt
#
# Processing file: 'husik, olivia j done.png'
#   Parsed FirstName='olivia', LastName='husik'
# [MATCH] olivia husik → Ohusik@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\Ohusik@mywinterhaven.com.png
#
# Processing file: 'hyman, frank w.jpg'
#   Parsed FirstName='frank', LastName='hyman'
# [NOT FOUND] no match for frank hyman
#
# Processing file: 'ibarra-contreras, alfonso.jpg'
#   Parsed FirstName='alfonso', LastName='ibarra-contreras'
# [NOT FOUND] no match for alfonso ibarra-contreras
#
# Processing file: 'irvis, damon c done.png'
#   Parsed FirstName='damon', LastName='irvis'
# [MATCH] damon irvis → dirvis@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\dirvis@mywinterhaven.com.png
#
# Processing file: 'isaac, teresa a done.png'
#   Parsed FirstName='teresa', LastName='isaac'
# [MATCH] teresa isaac → tisaac@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\tisaac@mywinterhaven.com.png
#
# Processing file: 'ivan garcia.png'
#   Parsed FirstName='ivan', LastName='garcia'
# [MATCH] ivan garcia → igarcia@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\igarcia@mywinterhaven.com.png
#
# Processing file: 'jackson, octavia l done.png'
#   Parsed FirstName='octavia', LastName='jackson'
# [MATCH] octavia jackson → ojackson@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ojackson@mywinterhaven.com.png
#
# Processing file: 'jairam, celina.png'
#   Parsed FirstName='celina', LastName='jairam'
# [MATCH] celina jairam → cjairam@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\cjairam@mywinterhaven.com.png
#
# Processing file: 'jairam, kishore s done.png'
#   Parsed FirstName='kishore', LastName='jairam'
# [MATCH] kishore jairam → kjairam@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\kjairam@mywinterhaven.com.png
#
# Processing file: 'james, matthew e jr_.jpg'
#   Parsed FirstName='matthew', LastName='james'
# [NOT FOUND] no match for matthew james
#
# Processing file: 'jarosek, jeremiah done.png'
#   Parsed FirstName='jeremiah', LastName='jarosek'
# [MATCH] jeremiah jarosek → jjarosek@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jjarosek@mywinterhaven.com.png
#
# Processing file: 'jarvis, lisa.png'
#   Parsed FirstName='lisa', LastName='jarvis'
# [NOT FOUND] no match for lisa jarvis
#
# Processing file: 'jenkins, amy done.png'
#   Parsed FirstName='amy', LastName='jenkins'
# [MATCH] amy jenkins → ajenkins@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ajenkins@mywinterhaven.com.png
#
# Processing file: 'jeremy murray.png'
#   Parsed FirstName='jeremy', LastName='murray'
# [NOT FOUND] no match for jeremy murray
#
# Processing file: 'john blits.png'
#   Parsed FirstName='john', LastName='blits'
# [MATCH] john blits → jblits@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jblits@mywinterhaven.com.png
#
# Processing file: 'john carnley.png'
#   Parsed FirstName='john', LastName='carnley'
# [MATCH] john carnley → jcarnley@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jcarnley@mywinterhaven.com.png
#
# Processing file: 'johnson, patricia.png'
#   Parsed FirstName='patricia', LastName='johnson'
# [MATCH] patricia johnson → pjohnson@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\pjohnson@mywinterhaven.com.png
#
# Processing file: 'jones, dan t done.png'
#   Parsed FirstName='dan', LastName='jones'
# [MATCH] dan jones → djones@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\djones@mywinterhaven.com.png
#
# Processing file: 'jose morales.png'
#   Parsed FirstName='jose', LastName='morales'
# [NOT FOUND] no match for jose morales
#
# Processing file: 'joshua crosby.png'
#   Parsed FirstName='joshua', LastName='crosby'
# [MATCH] joshua crosby → jcrosby@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jcrosby@mywinterhaven.com.png
#
# Processing file: 'joshua lee hendrix.png'
#   Parsed FirstName='joshua', LastName='hendrix'
# [MATCH] joshua hendrix → jhendrix@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jhendrix@mywinterhaven.com.png
#
# Processing file: 'juarez, robert c.png'
#   Parsed FirstName='robert', LastName='juarez'
# [NOT FOUND] no match for robert juarez
#
# Processing file: 'jurewicz, sharon k done.png'
#   Parsed FirstName='sharon', LastName='jurewicz'
# [MATCH] sharon jurewicz → sjurewicz@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\sjurewicz@mywinterhaven.com.png
#
# Processing file: 'karen, ball.png'
#   Parsed FirstName='ball', LastName='karen'
# [NOT FOUND] no match for ball karen
#
# Processing file: 'kemker, jason t.png'
#   Parsed FirstName='jason', LastName='kemker'
# [MATCH] jason kemker → jkemker@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jkemker@mywinterhaven.com.png
#
# Processing file: 'kenneth frank.png'
#   Parsed FirstName='kenneth', LastName='frank'
# [MATCH] kenneth frank → kfrank@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\kfrank@mywinterhaven.com.png
#
# Processing file: 'kester, edward j jr_.jpg'
#   Parsed FirstName='edward', LastName='kester'
# [MATCH] edward kester → ekester@mywinerhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ekester@mywinerhaven.com.jpg
#
# Processing file: 'kevin fairbanks.png'
#   Parsed FirstName='kevin', LastName='fairbanks'
# [NOT FOUND] no match for kevin fairbanks
#
# Processing file: 'khan, aizan ddone.png'
#   Parsed FirstName='aizan', LastName='khan'
# [MATCH] aizan khan → akhan@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\akhan@mywinterhaven.com.png
#
# Processing file: 'king, jimmy done.png'
#   Parsed FirstName='jimmy', LastName='king'
# [NOT FOUND] no match for jimmy king
#
# Processing file: 'king, kassidy r done.png'
#   Parsed FirstName='kassidy', LastName='king'
# [MATCH] kassidy king → kking@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\kking@mywinterhaven.com.png
#
# Processing file: 'kithcart, chloe e done.png'
#   Parsed FirstName='chloe', LastName='kithcart'
# [MATCH] chloe kithcart → ckithcart@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ckithcart@mywinterhaven.com.png
#
# Processing file: 'kline, tiffani n.jpg'
#   Parsed FirstName='tiffani', LastName='kline'
# [MATCH] tiffani kline → tkline@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\tkline@mywinterhaven.com.jpg
#
# Processing file: 'koenig, leigh.png'
#   Parsed FirstName='leigh', LastName='koenig'
# [MATCH] leigh koenig → lkoenig@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\lkoenig@mywinterhaven.com.png
#
# Processing file: 'labbe, eric c done.png'
#   Parsed FirstName='eric', LastName='labbe'
# [MATCH] eric labbe → elabbe@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\elabbe@mywinterhaven.com.png
#
# Processing file: 'lafollette, michael tdone.png'
#   Parsed FirstName='michael', LastName='lafollette'
# [MATCH] michael lafollette → mlafollette@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\mlafollette@mywinterhaven.com.png
#
# Processing file: 'lafon, stephanie m.png'
#   Parsed FirstName='stephanie', LastName='lafon'
# [NOT FOUND] no match for stephanie lafon
#
# Processing file: 'lambert, sandra b.jpg'
#   Parsed FirstName='sandra', LastName='lambert'
# [MATCH] sandra lambert → slambert@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\slambert@mywinterhaven.com.jpg
#
# Processing file: 'lamons, steven e done.png'
#   Parsed FirstName='steven', LastName='lamons'
# [NOT FOUND] no match for steven lamons
#
# Processing file: 'lane, robert d done.png'
#   Parsed FirstName='robert', LastName='lane'
# [MATCH] robert lane → blane@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\blane@mywinterhaven.com.png
#
# Processing file: 'large, skyla n done.png'
#   Parsed FirstName='skyla', LastName='large'
# [MATCH] skyla large → slarge@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\slarge@mywinterhaven.com.png
#
# Processing file: 'lari maldonado.png'
#   Parsed FirstName='lari', LastName='maldonado'
# [NOT FOUND] no match for lari maldonado
#
# Processing file: 'leach, jarred s done.png'
#   Parsed FirstName='jarred', LastName='leach'
# [NOT FOUND] no match for jarred leach
#
# Processing file: 'lee, samise p.png'
#   Parsed FirstName='samise', LastName='lee'
# [MATCH] samise lee → slee@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\slee@mywinterhaven.com.png
#
# Processing file: 'legee, james a done.png'
#   Parsed FirstName='james', LastName='legee'
# [MATCH] james legee → jlegee@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jlegee@mywinterhaven.com.png
#
# Processing file: 'lewis, delroy j.jpg'
#   Parsed FirstName='delroy', LastName='lewis'
# [NOT FOUND] no match for delroy lewis
#
# Processing file: 'lightsey, kandace m done.png'
#   Parsed FirstName='kandace', LastName='lightsey'
# [MATCH] kandace lightsey → klightsey@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\klightsey@mywinterhaven.com.png
#
# Processing file: 'lizalde, pedro a done.png'
#   Parsed FirstName='pedro', LastName='lizalde'
# [NOT FOUND] no match for pedro lizalde
#
# Processing file: 'lopez, jose l.png'
#   Parsed FirstName='jose', LastName='lopez'
# [MATCH] jose lopez → jlopez@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jlopez@mywinterhaven.com.png
#
# Processing file: 'lora, carlos j done.png'
#   Parsed FirstName='carlos', LastName='lora'
# [MATCH] carlos lora → clora@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\clora@mywinterhaven.com.png
#
# Processing file: 'lowe, michael l.jpg'
#   Parsed FirstName='michael', LastName='lowe'
# [MATCH] michael lowe → mlowe@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\mlowe@mywinterhaven.com.jpg
#
# Processing file: 'luann corby.png'
#   Parsed FirstName='luann', LastName='corby'
# [MATCH] luann corby → lcorby@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\lcorby@mywinterhaven.com.png
#
# Processing file: 'maldonado, lari.jpg'
#   Parsed FirstName='lari', LastName='maldonado'
# ...
#
# Processing file: 'russell, dylan g done.png'
#   Parsed FirstName='dylan', LastName='russell'
# [MATCH] dylan russell → drussell@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\drussell@mywinterhaven.com.png
#
# Processing file: 'saca, tommy e ii.jpg'
#   Parsed FirstName='tommy', LastName='saca'
# [NOT FOUND] no match for tommy saca
#
# Processing file: 'salyers, phillip m.jpg'
#   Parsed FirstName='phillip', LastName='salyers'
# [MATCH] phillip salyers → psalyers@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\psalyers@mywinterhaven.com.jpg
#
# Processing file: 'sanders, demetrius.png'
#   Parsed FirstName='demetrius', LastName='sanders'
# [MATCH] demetrius sanders → dsanders@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\dsanders@mywinterhaven.com.png
#
# Processing file: 'santiago lugaro, elliott j done.png'
#   Parsed FirstName='elliott', LastName='santiago lugaro'
# [NOT FOUND] no match for elliott santiago lugaro
#
# Processing file: 'santibanez-rivera, lizvette.png'
#   Parsed FirstName='lizvette', LastName='santibanez-rivera'
# [NOT FOUND] no match for lizvette santibanez-rivera
#
# Processing file: 'schemmel, michael s.png'
#   Parsed FirstName='michael', LastName='schemmel'
# [MATCH] michael schemmel → mschemmel@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\mschemmel@mywinterhaven.com.png
#
# Processing file: 'schofstoll, deborah done.png'
#   Parsed FirstName='deborah', LastName='schofstoll'
# [NOT FOUND] no match for deborah schofstoll
#
# Processing file: 'schoonmaker, heather d done.png'
#   Parsed FirstName='heather', LastName='schoonmaker'
# [MATCH] heather schoonmaker → hschoonmaker@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\hschoonmaker@mywinterhaven.com.png
#
# Processing file: 'schuwerk, michael j done.png'
#   Parsed FirstName='michael', LastName='schuwerk'
# [MATCH] michael schuwerk → mschuwerk@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\mschuwerk@mywinterhaven.com.png
#
# Processing file: 'scott, colleen j done.png'
#   Parsed FirstName='colleen', LastName='scott'
# [NOT FOUND] no match for colleen scott
#
# Processing file: 'segarra, lynn e.png'
#   Parsed FirstName='lynn', LastName='segarra'
# [MATCH] lynn segarra → lsegarra@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\lsegarra@mywinterhaven.com.png
#
# Processing file: 'serrano nieves, jean c done.png'
#   Parsed FirstName='jean', LastName='serrano nieves'
# [NOT FOUND] no match for jean serrano nieves
#
# Processing file: 'shelton, christopher k.png'
#   Parsed FirstName='christopher', LastName='shelton'
# [MATCH] christopher shelton → cshelton@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\cshelton@mywinterhaven.com.png
#
# Processing file: 'sidwell, taner k done.png'
#   Parsed FirstName='taner', LastName='sidwell'
# [NOT FOUND] no match for taner sidwell
#
# Processing file: 'simmons, eddie done.png'
#   Parsed FirstName='eddie', LastName='simmons'
# [MATCH] eddie simmons → jsimmons@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jsimmons@mywinterhaven.com.png
#
# Processing file: 'simmons, jeffrey w done.png'
#   Parsed FirstName='jeffrey', LastName='simmons'
# [MATCH] jeffrey simmons → jwsimmons@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jwsimmons@mywinterhaven.com.png
#
# Processing file: 'singh, vadewantie done.png'
#   Parsed FirstName='vadewantie', LastName='singh'
# [MATCH] vadewantie singh → vsingh@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\vsingh@mywinterhaven.com.png
#
# Processing file: 'small, carlington a done.png'
#   Parsed FirstName='carlington', LastName='small'
# [NOT FOUND] no match for carlington small
#
# Processing file: 'soleyn, tishawna a done.png'
#   Parsed FirstName='tishawna', LastName='soleyn'
# [MATCH] tishawna soleyn → tsoleyn@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\tsoleyn@mywinterhaven.com.png
#
# Processing file: 'soto velez, yenitza done.png'
#   Parsed FirstName='yenitza', LastName='soto velez'
# [NOT FOUND] no match for yenitza soto velez
#
# Processing file: 'spann, richard b done.png'
#   Parsed FirstName='richard', LastName='spann'
# [MATCH] richard spann → rspann@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\rspann@mywinterhaven.com.png
#
# Processing file: 'sperry, jordan a.png'
#   Parsed FirstName='jordan', LastName='sperry'
# [MATCH] jordan sperry → jsperry@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jsperry@mywinterhaven.com.png
#
# Processing file: 'sriram, mohendra.jpg'
#   Parsed FirstName='mohendra', LastName='sriram'
# [MATCH] mohendra sriram → msriram@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\msriram@mywinterhaven.com.jpg
#
# Processing file: 'stauffer, bruce s.png'
#   Parsed FirstName='bruce', LastName='stauffer'
# [MATCH] bruce stauffer → bstauffer@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\bstauffer@mywinterhaven.com.png
#
# Processing file: 'stone, joshua sdone.png'
#   Parsed FirstName='joshua', LastName='stone'
# [MATCH] joshua stone → jstone@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jstone@mywinterhaven.com.png
#
# Processing file: 'suarez, angel l.png'
#   Parsed FirstName='angel', LastName='suarez'
# [MATCH] angel suarez → asuarez@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\asuarez@mywinterhaven.com.png
#
# Processing file: 'suarez, estebandone.png'
#   Parsed FirstName='estebandone', LastName='suarez'
# [NOT FOUND] no match for estebandone suarez
#
# Processing file: 't. michael stavers done .png'
#   Parsed FirstName='t.', LastName='done'
# [NOT FOUND] no match for t. done
#
# Processing file: 'talley, terry l done.png'
#   Parsed FirstName='terry', LastName='talley'
# [MATCH] terry talley → ttalley@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ttalley@mywinterhaven.com.png
#
# Processing file: 'tate, deborah done.png'
#   Parsed FirstName='deborah', LastName='tate'
# [NOT FOUND] no match for deborah tate
#
# Processing file: 'taylor, christopher l.png'
#   Parsed FirstName='christopher', LastName='taylor'
# [MATCH] christopher taylor → ctaylor@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ctaylor@mywinterhaven.com.png
#
# Processing file: 'taylor, daniel j done.png'
#   Parsed FirstName='daniel', LastName='taylor'
# [MATCH] daniel taylor → dtaylor@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\dtaylor@mywinterhaven.com.png
#
# Processing file: 'taylor, haley k done.png'
#   Parsed FirstName='haley', LastName='taylor'
# [MATCH] haley taylor → htaylor@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\htaylor@mywinterhaven.com.png
#
# Processing file: 'thomas, tracy l done.png'
#   Parsed FirstName='tracy', LastName='thomas'
# [MATCH] tracy thomas → tthomas@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\tthomas@mywinterhaven.com.png
#
# Processing file: 'thompson, jesse w done.png'
#   Parsed FirstName='jesse', LastName='thompson'
# [MATCH] jesse thompson → sthompson@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\sthompson@mywinterhaven.com.png
#
# Processing file: 'thornhill, mary e done.png'
#   Parsed FirstName='mary', LastName='thornhill'
# [MATCH] mary thornhill → mthornhill@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\mthornhill@mywinterhaven.com.png
#
# Processing file: 'titus, corinne a done.png'
#   Parsed FirstName='corinne', LastName='titus'
# [MATCH] corinne titus → ctitus@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\ctitus@mywinterhaven.com.png
#
# Processing file: 'torres-rodriguez, jorge done.png'
#   Parsed FirstName='jorge', LastName='torres-rodriguez'
# [NOT FOUND] no match for jorge torres-rodriguez
#
# Processing file: 'trinidad, angel m.png'
#   Parsed FirstName='angel', LastName='trinidad'
# [MATCH] angel trinidad → atrinidad@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\atrinidad@mywinterhaven.com.png
#
# Processing file: 'turner, christopher m done.png'
#   Parsed FirstName='christopher', LastName='turner'
# [MATCH] christopher turner → cturner@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\cturner@mywinterhaven.com.png
#
# Processing file: 'turner, mark s done.png'
#   Parsed FirstName='mark', LastName='turner'
# [MATCH] mark turner → mturner@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\mturner@mywinterhaven.com.png
#
# Processing file: 'van druten, robert m.png'
#   Parsed FirstName='robert', LastName='van druten'
# [MATCH] robert van druten → rvandruten@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\rvandruten@mywinterhaven.com.png
#
# Processing file: 'vaughn, robert a.png'
#   Parsed FirstName='robert', LastName='vaughn'
# [MATCH] robert vaughn → rvaughn@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\rvaughn@mywinterhaven.com.png
#
# Processing file: 'vega, jose.png'
#   Parsed FirstName='jose', LastName='vega'
# [MATCH] jose vega → jvega@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jvega@mywinterhaven.com.png
#
# Processing file: 'vicedomini, joseph m done.png'
#   Parsed FirstName='joseph', LastName='vicedomini'
# [MATCH] joseph vicedomini → jvicedomini@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jvicedomini@mywinterhaven.com.png
#
# Processing file: 'vose, thomas a done.png'
#   Parsed FirstName='thomas', LastName='vose'
# [MATCH] thomas vose → tvose@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\tvose@mywinterhaven.com.png
#
# Processing file: 'wagner, julianna l done.png'
#   Parsed FirstName='julianna', LastName='wagner'
# [MATCH] julianna wagner → jwagner@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jwagner@mywinterhaven.com.png
#
# Processing file: 'wampler, holly f done.png'
#   Parsed FirstName='holly', LastName='wampler'
# [MATCH] holly wampler → hwampler@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\hwampler@mywinterhaven.com.png
#
# Processing file: 'warder, steven d done.png'
#   Parsed FirstName='steven', LastName='warder'
# [MATCH] steven warder → swarder@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\swarder@mywinterhaven.com.png
#
# Processing file: 'warren, jordan e done.png'
#   Parsed FirstName='jordan', LastName='warren'
# [MATCH] jordan warren → jwarren@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\jwarren@mywinterhaven.com.png
#
# Processing file: 'washington, myron o done.png'
#   Parsed FirstName='myron', LastName='washington'
# [MATCH] myron washington → mwashington@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\mwashington@mywinterhaven.com.png
#
# Processing file: 'watson, barbara n.jpg'
#   Parsed FirstName='barbara', LastName='watson'
# [MATCH] barbara watson → bwatson@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\bwatson@mywinterhaven.com.jpg
#
# Processing file: 'weeks, joseph a done.png'
#   Parsed FirstName='joseph', LastName='weeks'
# [MATCH] joseph weeks → aweeks@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\aweeks@mywinterhaven.com.png
#
# Processing file: 'wells, brian a done.png'
#   Parsed FirstName='brian', LastName='wells'
# [MATCH] brian wells → bwells@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\bwells@mywinterhaven.com.png
#
# Processing file: 'wells, robert n done.png'
#   Parsed FirstName='robert', LastName='wells'
# [NOT FOUND] no match for robert wells
#
# Processing file: 'white, katie e done.png'
#   Parsed FirstName='katie', LastName='white'
# [MATCH] katie white → kwhite@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\kwhite@mywinterhaven.com.png
#
# Processing file: 'williams, benjamin w done.png'
#   Parsed FirstName='benjamin', LastName='williams'
# [MATCH] benjamin williams → bwilliams@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\bwilliams@mywinterhaven.com.png
#
# Processing file: 'williams, benjamin w.png'
#   Parsed FirstName='benjamin', LastName='williams'
# [MATCH] benjamin williams → bwilliams@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\bwilliams@mywinterhaven.com.png
#
# Processing file: 'williams, christina r done.png'
#   Parsed FirstName='christina', LastName='williams'
# [MATCH] christina williams → cwilliams@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\cwilliams@mywinterhaven.com.png
#
# Processing file: 'williams, tyler d.jpg'
#   Parsed FirstName='tyler', LastName='williams'
# [MATCH] tyler williams → tdwilliams@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\tdwilliams@mywinterhaven.com.jpg
#
# Processing file: 'wilson, natalie k done.png'
#   Parsed FirstName='natalie', LastName='wilson'
# [MATCH] natalie wilson → nwilson@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\nwilson@mywinterhaven.com.png
#
# Processing file: 'winder, daekwon l done.png'
#   Parsed FirstName='daekwon', LastName='winder'
# [NOT FOUND] no match for daekwon winder
#
# Processing file: 'winstanley, savannah done.png'
#   Parsed FirstName='savannah', LastName='winstanley'
# [MATCH] savannah winstanley → swinstanley@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\swinstanley@mywinterhaven.com.png
#
# Processing file: 'wint, bjorn j done.png'
#   Parsed FirstName='bjorn', LastName='wint'
# [MATCH] bjorn wint → bwint@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\bwint@mywinterhaven.com.png
#
# Processing file: 'winters (bowles), kayla c done.png'
#   Parsed FirstName='kayla', LastName='winters (bowles)'
# [NOT FOUND] no match for kayla winters (bowles)
#
# Processing file: 'wisham, amanda j done.png'
#   Parsed FirstName='amanda', LastName='wisham'
# [MATCH] amanda wisham → awisham@mywinterhaven.com
# [OK] cropped & saved → C:\Users\dtaylor\Documents\Jostle Pictures Project\jostleupload3\awisham@mywinterhaven.com.png
#
# Processing file: 'wood, douglas j.png'
#   Parsed FirstName='douglas', LastName='wood'
# [NOT FOUND] no match for douglas wood
#
# Processing file: 'young, christopher d done.png'
#   Parsed FirstName='christopher', LastName='young'
# [NOT FOUND] no match for christopher young

# %%
# CHGATGPT

import os
import pandas as pd
import cv2

# your network/share paths—use raw strings so backslashes aren’t swallowed as escapes
INPUT_DIR  = r"C:\Users\dtaylor\Documents\ALLIDS"
OUTPUT_DIR = r"C:\Users\dtaylor\Documents\ALLIDS\jostleupload"
CSV_PATH   = r"C:\Users\dtaylor\Documents\jostleNoPhoto.csv"

# make sure the output directory exists
os.makedirs(OUTPUT_DIR, exist_ok=True)

# load your DataFrame
df = pd.read_csv(CSV_PATH, encoding='utf-8', low_memory=False)
print(df)

def crop_and_save(img_path: str, email: str, file_ext: str):
    img = cv2.imread(img_path)
    if img is None:
        print(f"[ERROR] failed to load image: {img_path}")
        return
    
    # crop coordinates: adjust as you wish
    crop_img = img[563:1150, 500:960]
    
    out_path = os.path.join(OUTPUT_DIR, f"{email}{file_ext}")
    success = cv2.imwrite(out_path, crop_img)
    if success:
        print(f"[OK] cropped & saved → {out_path}")
    else:
        print(f"[ERROR] could not save cropped image to {out_path}")

# loop through all your png/jpg/jpeg files
for fname in os.listdir(INPUT_DIR):
    low = fname.lower()
    if not (low.endswith(".jpg") or low.endswith(".jpeg") or low.endswith(".png")):
        continue

    # assume the first “word” in the filename is the first name
    last_name = fname.split()[0].strip(",")
    print(f"Checking name → {last_name}")

    if last_name in df['LastName'].values:
        print(f"  Found in DataFrame: {last_name}")
        row   = df.loc[df['LastNameName'] == last_name].iloc[0]
        email = row['WorkEmail']
        ext   = os.path.splitext(fname)[1]

        full_input_path = os.path.join(INPUT_DIR, fname)
        crop_and_save(full_input_path, email, ext)
    else:
        print(f"  NOT found in DataFrame: {last_name}")

    # if you only want to test the first one, un-comment the next line:
    break
# Out:
#                        WorkEmail  FirstName  LastName
# 0        rbach@mywinterhaven.com     ronald      bach
# 1       sbyers@mywinterhaven.com       sean     byers
# 2    mwilliams@mywinterhaven.com    michael  williams
# 3     ggardner@mywinterhaven.com  gabrielle   gardner
# 4      jcrosby@mywinterhaven.com     joshua    crosby
# ..                           ...        ...       ...
# 225   avaughan@mywinterhaven.com     adrian   vaughan
# 226  hbraswell@mywinterhaven.com     hannah  braswell
# 227    fmacias@mywinterhaven.com     franky    macias
# 228   dmahalik@mywinterhaven.com      david   mahalik
# 229   tjenkins@mywinterhaven.com  taizhuana   jenkins
#
# [230 rows x 3 columns]
# Checking name → abdeljawad
#   NOT found in DataFrame: abdeljawad
